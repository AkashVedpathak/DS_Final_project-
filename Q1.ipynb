# %% [markdown]
# Q1. You work in a news agency & are responsible for identifying the most
# important topic for writing articles by your content team. Develop a
# Jupyter Notebook which on executing every time shows top 10 Twitter
# trending topics in India in the last 24 hours. Hints: Connecting with Twitter
# API. Bringing Dashboard-like behaviour in Jupyter notebook. Please note:
# Visualisation is mandatory. You will receive 0 marks if you do not add
# visualisation.

# %%
import tweepy
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
consumer_key='RaLwj04RG2kzCi3LQL4FDvFRI'
consumer_secret='yzKkYQw9C3ikGTISadoBTaQhwFF13Gcdw7jocRVPbZ06Oct0gN'
access_token='1201514536739557376-E5iYGefcOFDMGhmiQLx5c8ZSXDOVbK'
access_token_secret='kYHi2fuhlcTQvPdIJCgVbyulLaLAIGvhB0aXTHTU0D7IN'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
# Create API object
api = tweepy.API(auth)

# %%
woeid = 23424848

# %%
trends = api.get_place_trends(id = woeid)

# %%
ten_list = []
for value in trends:
    for trend in value['trends']:
        ten_list.append(trend['name'])

# %%
ten_list[0:10]
# Out:
# ['Order of the Nile',
#  '#DarkDaysOfEmergency',
#  '11 YEARS OF YUMNA ZAIDI',
#  '#NaddaJiInTelangana',
#  '#ProjectK',
#  'राष्ट्रपति अब्देल फतह',
#  'Egypt',
#  'BBOTT QUEEN MANISHA',
#  '#KamalHaasan',
#  'Tony Montana']

# %%
unique_string=(" ").join(ten_list)
wordcloud = WordCloud(width = 1000, height = 500).generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.savefig("your_file_name"+".png", bbox_inches='tight')
plt.show()
plt.close()
