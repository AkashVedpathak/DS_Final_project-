# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df2 = pd.read_csv(r"/content/Batchwise Attendance Data - Class 1.csv")

# %%
df2
# Out:
#     Student Roll Num     Type  10-01-21  R-10-01-21  09-01-21  R-9-01-21  \
# 0                  1  WORKING    Missed           9    Missed          7
# 1                  2      NaN    Missed           9    Missed          7
# 2                  3  STUDENT    Missed           6    Missed          7
# 3                  4  STUDENT    Missed           8    Missed          9
# 4                  5  WORKING    Missed           7    Missed          7
# 5                  6      NaN    Missed           8    Missed          9
# 6                  7  STUDENT  Attended           7  Attended          7
# 7                  8  STUDENT    Missed           5    Missed          9
# 8                  9   IGNORE    Missed           8    Missed          7
# 9                 10      NaN    Missed           9    Missed          6
# 10                11  STUDENT  Attended           7  Attended          9
# 11                12  STUDENT  Attended           7  Attended          9
# ...

# %%
df2.isna().sum()
# Out:
# Student Roll Num     0
# Type                25
# 10-01-21             0
# R-10-01-21           0
# 09-01-21             0
# R-9-01-21            0
# 08-01-21             0
# R-8-01-21            0
# 07-01-21             1
# R-7-01-21            0
# 06-01-21             1
# R-6-01-21            0
# 05-01-21             1
# R-5-01-21            0
# 04-01-21             1
# R-4-01-21            0
# 03-01-21             1
# R-3-01-21            0
# 02-01-21             1
# R-02-01-21           0
# 01-01-21             1
# R-01-01-21           0
# dtype: int64

# %%
df2.columns
# Out:
# Index(['Student Roll Num', 'Type', '10-01-21', 'R-10-01-21', '09-01-21',
#        'R-9-01-21', '08-01-21', 'R-8-01-21', '07-01-21', 'R-7-01-21',
#        '06-01-21', 'R-6-01-21', '05-01-21', 'R-5-01-21', '04-01-21',
#        'R-4-01-21', '03-01-21', 'R-3-01-21', '02-01-21', 'R-02-01-21',
#        '01-01-21', 'R-01-01-21'],
#       dtype='object')

# %%
df2.head()
# Out:
#    Student Roll Num     Type 10-01-21  R-10-01-21 09-01-21  R-9-01-21  \
# 0                 1  WORKING   Missed           9   Missed          7
# 1                 2      NaN   Missed           9   Missed          7
# 2                 3  STUDENT   Missed           6   Missed          7
# 3                 4  STUDENT   Missed           8   Missed          9
# 4                 5  WORKING   Missed           7   Missed          7
#
#    08-01-21  R-8-01-21  07-01-21  R-7-01-21  ...  05-01-21  R-5-01-21  \
# 0    Missed          6    Missed          6  ...    Missed         10
# 1    Missed          7  Attended          5  ...  Attended          9
# 2    Missed          7    Missed          7  ...  Attended          9
# 3  Attended          5    Missed          9  ...    Missed          9
# 4    Missed          8    Missed          9  ...    Missed          5
#
#    04-01-21  R-4-01-21  03-01-21  R-3-01-21  02-01-21  R-02-01-21  01-01-21  \
# ...

# %%
df2.columns
# Out:
# Index(['Student Roll Num', 'Type', '10-01-21', 'R-10-01-21', '09-01-21',
#        'R-9-01-21', '08-01-21', 'R-8-01-21', '07-01-21', 'R-7-01-21',
#        '06-01-21', 'R-6-01-21', '05-01-21', 'R-5-01-21', '04-01-21',
#        'R-4-01-21', '03-01-21', 'R-3-01-21', '02-01-21', 'R-02-01-21',
#        '01-01-21', 'R-01-01-21'],
#       dtype='object')

# %%
df2['Type']=df2['Type'].fillna('STUDENT')

# %%
df2['01-01-21']=df2['01-01-21'].fillna('Missed')

# %%
df3=df2[['R-10-01-21','R-9-01-21','R-8-01-21','R-7-01-21','R-6-01-21','R-5-01-21','R-4-01-21','R-3-01-21',]].mean()
df3
# Out:
# R-10-01-21    7.596491
# R-9-01-21     7.894737
# R-8-01-21     7.684211
# R-7-01-21     7.578947
# R-6-01-21     7.719298
# R-5-01-21     7.771930
# R-4-01-21     7.807018
# R-3-01-21     7.614035
# dtype: float64

# %%
df2['R-01-01-21']=df2['R-01-01-21'].fillna(7)

# %%
df2['R-01-01-21']= df2['R-01-01-21'].astype(int)

# %%
df2=df2.iloc[:,:-1]

# %%
df2
# Out:
#     Student Roll Num     Type  10-01-21  R-10-01-21  09-01-21  R-9-01-21  \
# 0                  1  WORKING    Missed           9    Missed          7
# 1                  2  STUDENT    Missed           9    Missed          7
# 2                  3  STUDENT    Missed           6    Missed          7
# 3                  4  STUDENT    Missed           8    Missed          9
# 4                  5  WORKING    Missed           7    Missed          7
# 5                  6  STUDENT    Missed           8    Missed          9
# 6                  7  STUDENT  Attended           7  Attended          7
# 7                  8  STUDENT    Missed           5    Missed          9
# 8                  9   IGNORE    Missed           8    Missed          7
# 9                 10  STUDENT    Missed           9    Missed          6
# 10                11  STUDENT  Attended           7  Attended          9
# 11                12  STUDENT  Attended           7  Attended          9
# ...

# %%
df2.shape
# Out:
# (57, 21)

# %%
df2.isna().sum()
# Out:
# Student Roll Num    0
# Type                0
# 10-01-21            0
# R-10-01-21          0
# 09-01-21            0
# R-9-01-21           0
# 08-01-21            0
# R-8-01-21           0
# 07-01-21            1
# R-7-01-21           0
# 06-01-21            1
# R-6-01-21           0
# 05-01-21            1
# R-5-01-21           0
# 04-01-21            1
# R-4-01-21           0
# 03-01-21            1
# R-3-01-21           0
# 02-01-21            1
# R-02-01-21          0
# 01-01-21            0
# dtype: int64

# %%
df2=df2.fillna("Missed")

# %%
df2.isna().sum()
# Out:
# Student Roll Num    0
# Type                0
# 10-01-21            0
# R-10-01-21          0
# 09-01-21            0
# R-9-01-21           0
# 08-01-21            0
# R-8-01-21           0
# 07-01-21            0
# R-7-01-21           0
# 06-01-21            0
# R-6-01-21           0
# 05-01-21            0
# R-5-01-21           0
# 04-01-21            0
# R-4-01-21           0
# 03-01-21            0
# R-3-01-21           0
# 02-01-21            0
# R-02-01-21          0
# 01-01-21            0
# dtype: int64

# %%
df2.head()
# Out:
#    Student Roll Num     Type 10-01-21  R-10-01-21 09-01-21  R-9-01-21  \
# 0                 1  WORKING   Missed           9   Missed          7
# 1                 2  STUDENT   Missed           9   Missed          7
# 2                 3  STUDENT   Missed           6   Missed          7
# 3                 4  STUDENT   Missed           8   Missed          9
# 4                 5  WORKING   Missed           7   Missed          7
#
#    08-01-21  R-8-01-21  07-01-21  R-7-01-21  ... R-6-01-21  05-01-21  \
# 0    Missed          6    Missed          6  ...        10    Missed
# 1    Missed          7  Attended          5  ...         6  Attended
# 2    Missed          7    Missed          7  ...         5  Attended
# 3  Attended          5    Missed          9  ...         9    Missed
# 4    Missed          8    Missed          9  ...         9    Missed
#
#   R-5-01-21  04-01-21 R-4-01-21  03-01-21 R-3-01-21  02-01-21 R-02-01-21  \
# ...

# %%
stud_count = df2[df2.Type == 'STUDENT'].shape[0]
stud_count
# Out:
# 45

# %%
stud_df = df2[df2["Type"].str.contains("STUDENT") == True]
stud_df
# Out:
#     Student Roll Num     Type  10-01-21  R-10-01-21  09-01-21  R-9-01-21  \
# 1                  2  STUDENT    Missed           9    Missed          7
# 2                  3  STUDENT    Missed           6    Missed          7
# 3                  4  STUDENT    Missed           8    Missed          9
# 5                  6  STUDENT    Missed           8    Missed          9
# 6                  7  STUDENT  Attended           7  Attended          7
# 7                  8  STUDENT    Missed           5    Missed          9
# 9                 10  STUDENT    Missed           9    Missed          6
# 10                11  STUDENT  Attended           7  Attended          9
# 11                12  STUDENT  Attended           7  Attended          9
# 12                13  STUDENT  Attended           5  Attended          7
# 13                14  STUDENT  Attended           6  Attended         10
# 16                17  STUDENT  Attended          10  Attended          8
# ...

# %%
stud_df.shape
# Out:
# (45, 21)

# %%
Attended_count = (stud_df == 'Attended').astype(object).sum(axis=1)

# %%
Attended_count.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 45 entries, 1 to 56
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 45 non-null     float64
# dtypes: float64(1)
# memory usage: 720.0 bytes

# %%
frame = {"Attended Count": Attended_count}

# %%
a_df = pd.DataFrame(frame)

# %%
a_df = a_df['Attended Count'] = a_df['Attended Count'].astype(int)

# %%
a_df.head()
# Out:
# 1     4
# 2     4
# 3     5
# 5     4
# 6    10
# Name: Attended Count, dtype: object

# %%
stud_df['Attended Count'] = a_df
# Out:
# <ipython-input-75-2959ca9abdae>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stud_df['Attended Count'] = a_df

# %%
stud_df.head(5)
# Out:
#    Student Roll Num     Type  10-01-21  R-10-01-21  09-01-21  R-9-01-21  \
# 1                 2  STUDENT    Missed           9    Missed          7
# 2                 3  STUDENT    Missed           6    Missed          7
# 3                 4  STUDENT    Missed           8    Missed          9
# 5                 6  STUDENT    Missed           8    Missed          9
# 6                 7  STUDENT  Attended           7  Attended          7
#
#    08-01-21  R-8-01-21  07-01-21  R-7-01-21  ...  05-01-21  R-5-01-21  \
# 1    Missed          7  Attended          5  ...  Attended          9
# 2    Missed          7    Missed          7  ...  Attended          9
# 3  Attended          5    Missed          9  ...    Missed          9
# 5    Missed          7    Missed         10  ...    Missed         10
# 6  Attended          7  Attended          5  ...  Attended          6
#
#    04-01-21  R-4-01-21  03-01-21  R-3-01-21  02-01-21  R-02-01-21  01-01-21  \
# ...

# %%
b=stud_df.select_dtypes(exclude='object')

# %%
b
# Out:
#     Student Roll Num  R-10-01-21  R-9-01-21  R-8-01-21  R-7-01-21  R-6-01-21  \
# 1                  2           9          7          7          5          6
# 2                  3           6          7          7          7          5
# 3                  4           8          9          5          9          9
# 5                  6           8          9          7         10          9
# 6                  7           7          7          7          5         10
# 7                  8           5          9         10          6          8
# 9                 10           9          6          9         10          8
# 10                11           7          9         10         10         10
# 11                12           7          9         10          7         10
# 12                13           5          7         10          7          9
# 13                14           6         10          8          7          6
# ...

# %%
k=b.drop(['Student Roll Num'],axis=1)

# %%
k
# Out:
#     R-10-01-21  R-9-01-21  R-8-01-21  R-7-01-21  R-6-01-21  R-5-01-21  \
# 1            9          7          7          5          6          9
# 2            6          7          7          7          5          9
# 3            8          9          5          9          9          9
# 5            8          9          7         10          9         10
# 6            7          7          7          5         10          6
# 7            5          9         10          6          8          7
# 9            9          6          9         10          8          6
# 10           7          9         10         10         10         10
# 11           7          9         10          7         10          6
# 12           5          7         10          7          9         10
# 13           6         10          8          7          6          8
# 16          10          8          6         10          7          7
# ...

# %%
rating_count = k.sum(axis = 1)

# %%
rating_count_avg = rating_count/100*100

# %%
rating_count_avg.astype(int)
# Out:
# 1     64
# 2     64
# 3     75
# 5     75
# 6     61
# 7     72
# 9     76
# 10    77
# 11    70
# 12    74
# 13    66
# 16    70
# 17    70
# 18    70
# 19    74
# 20    74
# 22    68
# 24    69
# 25    72
# 26    74
# 27    77
# 28    70
# 30    67
# 31    69
# 32    67
# 33    61
# 34    68
# 36    63
# 37    64
# 38    68
# 39    68
# 40    75
# 41    69
# 42    63
# 43    62
# 44    60
# 45    63
# 46    67
# 47    69
# 48    68
# 50    69
# 52    65
# 53    69
# 55    70
# 56    71
# dtype: int64

# %%
stud_df['rating_count_avg']= rating_count_avg
# Out:
# <ipython-input-84-d8637051ad52>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stud_df['rating_count_avg']= rating_count_avg

# %%
stud_df.head()
# Out:
#    Student Roll Num     Type  10-01-21  R-10-01-21  09-01-21  R-9-01-21  \
# 1                 2  STUDENT    Missed           9    Missed          7
# 2                 3  STUDENT    Missed           6    Missed          7
# 3                 4  STUDENT    Missed           8    Missed          9
# 5                 6  STUDENT    Missed           8    Missed          9
# 6                 7  STUDENT  Attended           7  Attended          7
#
#    08-01-21  R-8-01-21  07-01-21  R-7-01-21  ... R-5-01-21  04-01-21  \
# 1    Missed          7  Attended          5  ...         9  Attended
# 2    Missed          7    Missed          7  ...         9    Missed
# 3  Attended          5    Missed          9  ...         9  Attended
# 5    Missed          7    Missed         10  ...        10  Attended
# 6  Attended          7  Attended          5  ...         6  Attended
#
#   R-4-01-21  03-01-21 R-3-01-21  02-01-21 R-02-01-21  01-01-21 Attended Count  \
# ...

# %%
stud_dff = stud_df['rating_count_avg'] = stud_df['rating_count_avg'].astype(int)
# Out:
# <ipython-input-86-1830dd89b4cb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stud_dff = stud_df['rating_count_avg'] = stud_df['rating_count_avg'].astype(int)

# %%
stud_df
# Out:
#     Student Roll Num     Type  10-01-21  R-10-01-21  09-01-21  R-9-01-21  \
# 1                  2  STUDENT    Missed           9    Missed          7
# 2                  3  STUDENT    Missed           6    Missed          7
# 3                  4  STUDENT    Missed           8    Missed          9
# 5                  6  STUDENT    Missed           8    Missed          9
# 6                  7  STUDENT  Attended           7  Attended          7
# 7                  8  STUDENT    Missed           5    Missed          9
# 9                 10  STUDENT    Missed           9    Missed          6
# 10                11  STUDENT  Attended           7  Attended          9
# 11                12  STUDENT  Attended           7  Attended          9
# 12                13  STUDENT  Attended           5  Attended          7
# 13                14  STUDENT  Attended           6  Attended         10
# 16                17  STUDENT  Attended          10  Attended          8
# ...

# %%
low_attendance = stud_df[stud_df['Attended Count'] <= 4]
low_attendance
# Out:
#     Student Roll Num     Type 10-01-21  R-10-01-21 09-01-21  R-9-01-21  \
# 1                  2  STUDENT   Missed           9   Missed          7
# 2                  3  STUDENT   Missed           6   Missed          7
# 5                  6  STUDENT   Missed           8   Missed          9
# 7                  8  STUDENT   Missed           5   Missed          9
# 9                 10  STUDENT   Missed           9   Missed          6
# 17                18  STUDENT   Missed          10   Missed          5
# 18                19  STUDENT   Missed           9   Missed         10
# 20                21  STUDENT   Missed          10   Missed         10
# 22                23  STUDENT   Missed           6   Missed          8
# 26                27  STUDENT   Missed           9   Missed         10
# 31                32  STUDENT   Missed           5   Missed          6
# 32                33  STUDENT   Missed          10   Missed          6
# ...

# %%
# Assuming that the column representing attendance is named "attendance"
low_attendance = stud_df[stud_df['Attended Count'] <= 4]


low_attendance.plot(kind='bar', x='Student Roll Num', y='Attended Count', color='red')

plt.title("Students with low attendance")
plt.xlabel("Student Roll Number")
plt.ylabel("Attendance less than 4")

plt.show()



#more attension

# %%
low_attendance = stud_df[stud_df['rating_count_avg'] <= 65]


low_attendance.plot(kind='bar', x='Student Roll Num', y='rating_count_avg', color='red')

plt.title("Students are Unsatisfied")
plt.xlabel("Student Roll Number")
plt.ylabel("Rating count avg")

plt.show()

# %%
low_attendance = stud_df[stud_df['rating_count_avg'] > 70]
low_attendance.plot(kind='bar', x='Student Roll Num', y='rating_count_avg', color='red')
plt.title("Students are Very Satisfied")
plt.xlabel("Student Roll Number")
plt.ylabel("Rating count avg")
plt.show()

# %%
# averge Student ratng
low_attendance = stud_df[(stud_df['rating_count_avg'] >= 75) & (stud_df['rating_count_avg']<=80)]
low_attendance.plot(kind='bar', x='Student Roll Num', y='rating_count_avg', color='blue')
plt.title("Students are average performace ")
plt.xlabel("Student Roll Number")
plt.ylabel("Rating count avg")
# Out:
# Text(0, 0.5, 'Rating count avg')
